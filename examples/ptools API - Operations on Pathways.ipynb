# %%
#to run the script, you need to start pathway tools form the command line 
# using the -lisp -python options. Example (from the pathway tools github repository)
import os
# os.system('nohup /opt/pathway-tools/pathway-tools -lisp -python &')
os.system('nohup /opt/pathway-tools/pathway-tools -lisp -python-local-only &') # added cybersecurity
os.system('nohup /shared/D1/opt/pathway-tools/pathway-tools -lisp -python-local-only &') # added cybersecurity
# Out:
# 0

# %%
# modify sys.path to recognize local pythoncyc
import os
import sys
module_path = os.path.abspath(os.path.join('./PythonCyc/'))
sys.path = [module_path]

sys.path
# Out:
# ['/home/glucksfall/Dropbox/modding-pythoncyc/PythonCyc']

# %%
# remove pyc files
# !rm ./PythonCyc/pythoncyc/*pyc

import pythoncyc
all_orgids = pythoncyc.all_orgids()
print all_orgids

meta = pythoncyc.select_organism(u'|META|')
ecoli = pythoncyc.select_organism(u'|ECOLI|')
# Out:
# [u'|META|', u'|ECOLI|']

# %%
"""
pwy
An instance of the class |Pathways|. 
sorted?
Keyword, Optional If true, the genes are sorted in the order in which the 
corresponding reaction occurrs in the sequence of the pathway. 
"""

lst = []
for pwy in ecoli.all_pathways(selector = 'all', base = True):
    lst.append(ecoli.genes_of_pathway(pwy = pwy, sorted = True))
lst[-1]

# sorted arg doesn't work because malformed key. sorted changed to sorted?
# Out:
# all-pathways
# (all-pathways :all t )
# (with-organism (:org-id '|ECOLI|) (all-pathways :all t ))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1347| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1347| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1474| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1474| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-6690| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-6690| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1348| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1348| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-5162| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-5162| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1352| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1352| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1505| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1505| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1355| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1355| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|2PHENDEG-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|2PHENDEG-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1465| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1465| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|TRESYN-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|TRESYN-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PANTO-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PANTO-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1356| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1356| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|ETOH-ACETYLCOA-ANA-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|ETOH-ACETYLCOA-ANA-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1483| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1483| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1573| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1573| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1586| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1586| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|GLUCONSUPER-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|GLUCONSUPER-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1576| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1576| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|GLYCEROLMETAB-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|GLYCEROLMETAB-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1512| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1512| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1577| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1577| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-5123| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-5123| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1313| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1313| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-6387| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-6387| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PYRIDNUCSAL-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PYRIDNUCSAL-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1578| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1578| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1490| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1490| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1581| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1581| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY3O-4106| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY3O-4106| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|KDOSYN-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|KDOSYN-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-7761| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-7761| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1582| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1582| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-7971| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-7971| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1534| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1534| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-6952| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-6952| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1518| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1518| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-7184| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-7184| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1584| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1584| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-6038| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-6038| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PYRIDNUCSYN-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PYRIDNUCSYN-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1585| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1585| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-981| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-981| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1495| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1495| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-7181| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-7181| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-7801| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-7801| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PYRUVDEHYD-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PYRUVDEHYD-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-5509| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-5509| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-5350| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-5350| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1559| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1559| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|ALKANEMONOX-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|ALKANEMONOX-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|HOMOSER-METSYN-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|HOMOSER-METSYN-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-6153| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-6153| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1535| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1535| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-7206| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-7206| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|AST-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|AST-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-5340| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-5340| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-823| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-823| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-541| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-541| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|THREONINE-DEG2-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|THREONINE-DEG2-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-5971| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-5971| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-5436| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-5436| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-7197| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-7197| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|THRDLCTCAT-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|THRDLCTCAT-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1533| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1533| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-5437| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-5437| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|TRNA-CHARGING-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|TRNA-CHARGING-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|LCYSDEG-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|LCYSDEG-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-6703| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-6703| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1517| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1517| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|GLYCLEAV-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|GLYCLEAV-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|GALACTARDEG-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|GALACTARDEG-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-7446| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-7446| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY-7980| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY-7980| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|ALADEG-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|ALADEG-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|COA-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|COA-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|HOMOSERSYN-PWY| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|HOMOSERSYN-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|GLYOXYLATE-BYPASS| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|GLYOXYLATE-BYPASS| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '
:sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|HCAMHPDEG-PWY| :sorted? t))
# genes-of-pathway
# (genes-of-pathway '|PWY0-1336| :sorted? t)
# (with-organism (:org-id '|ECOLI|) (genes-of-pathway '|PWY0-1336| :sorted? t))
# [u'|EG12082|',
#  u'|EG12088|',
#  u'|EG12090|',
#  u'|EG12091|',
#  u'|EG12092|',
#  u'|EG11773|',
#  u'|EG12093|',
#  u'|EG12089|',
#  u'|EG12087|',
#  u'|EG11774|',
#  u'|EG12086|',
#  u'|EG12084|',
#  u'|EG12083|',
#  u'|EG10330|',
#  u'|EG10331|',
#  u'|EG10332|',
#  u'|EG10333|']

# %%
"""
pwy
An instance of the class |Pathways|. 
species
Keyword, Optional A list of species, such that in a multi-organism PGDB such as 
MetaCyc, only proteins found in those organisms will be returned. This list can 
include valid org‑ids, children of class |Organisms|, and strings. Please see 
the documentation for the 'species slot‑unit for more information. 
experimental-only?
Keyword, Optional When true, only return enzymes that have a non-computational 
evidence code associated with it. 
sorted?
Keyword, Optional If true, the enzymes are sorted in the order in which the 
corresponding reaction occurrs in the sequence of the pathway. 
"""

lst = []
for pwy in ecoli.all_pathways(selector = ':all', base = True):
    lst.append(ecoli.enzymes_of_pathway(pwy = pwy, sorted = True, experimental_only = True))
lst[-1]

# same as previous function
# Out:
# all-pathways
# (all-pathways ::all t )
# (with-organism (:org-id '|ECOLI|) (all-pathways ::all t ))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1347| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1347| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1474| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1474| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6690| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6690| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1348| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1348| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-5162| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-5162| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1352| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1352| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1505| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1505| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1355| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1355| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|2PHENDEG-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|2PHENDEG-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1465| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1465| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|TRESYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|TRESYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PANTO-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PANTO-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1356| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1356| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|ETOH-ACETYLCOA-ANA-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|ETOH-ACETYLCOA-ANA-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1483| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1483| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1573| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1573| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1586| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1586| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GLUCONSUPER-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GLUCONSUPER-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1576| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1576| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GLYCEROLMETAB-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GLYCEROLMETAB-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1512| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1512| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1577| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1577| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-5123| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-5123| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1313| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1313| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6387| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6387| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PYRIDNUCSAL-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PYRIDNUCSAL-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1578| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1578| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1490| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1490| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1581| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1581| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY3O-4106| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY3O-4106| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|KDOSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|KDOSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7761| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7761| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1582| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1582| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7971| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7971| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1534| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1534| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6952| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6952| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1518| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1518| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7184| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7184| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1584| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1584| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6038| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6038| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PYRIDNUCSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PYRIDNUCSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1585| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1585| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-981| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-981| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1495| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1495| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7181| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7181| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7801| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7801| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PYRUVDEHYD-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PYRUVDEHYD-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-5509| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-5509| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-5350| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-5350| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1559| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1559| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|ALKANEMONOX-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|ALKANEMONOX-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|HOMOSER-METSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|HOMOSER-METSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6153| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6153| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1535| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1535| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7206| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7206| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|AST-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|AST-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-5340| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-5340| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-823| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-823| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-541| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-541| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|THREONINE-DEG2-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|THREONINE-DEG2-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-5971| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-5971| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-5436| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-5436| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7197| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7197| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|THRDLCTCAT-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|THRDLCTCAT-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1533| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1533| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-5437| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-5437| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|TRNA-CHARGING-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|TRNA-CHARGING-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|LCYSDEG-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|LCYSDEG-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6703| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6703| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1517| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1517| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GLYCLEAV-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GLYCLEAV-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GALACTARDEG-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GALACTARDEG-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7446| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7446| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7980| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7980| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|ALADEG-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|ALADEG-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|COA-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|COA-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|HOMOSERSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|HOMOSERSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GLYOXYLATE-BYPASS| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GLYOXYLATE-BYPASS| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|SERDEG-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|SERDEG-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6163| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6163| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GLUTAMINDEG-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GLUTAMINDEG-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0
YN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|ASPARTATESYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1221| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1221| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7343| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7343| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|NAGLIPASYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|NAGLIPASYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1482| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1482| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PUTDEG-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PUTDEG-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|TRPSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|TRPSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|CARNMET-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|CARNMET-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7335| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7335| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-5837| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-5837| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|KDO-LIPASYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|KDO-LIPASYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1509| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1509| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GLNSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GLNSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1471| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1471| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7346| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7346| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6708| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6708| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1487| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1487| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-5084| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-5084| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1261| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1261| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|ILEUSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|ILEUSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7544| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7544| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1241| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1241| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|UDPNAGSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|UDPNAGSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|MENAQUINONESYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|MENAQUINONESYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1515| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1515| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7545| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7545| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|ASPARAGINESYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|ASPARAGINESYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|FASYN-ELONG-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|FASYN-ELONG-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1329| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1329| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6123| :experimental-only? t :sorted? t)
# ...
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1353| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-5966| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-5966| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|HOMOSER-THRESYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|HOMOSER-THRESYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1544| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1544| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|NONMEVIPP-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|NONMEVIPP-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1498| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1498| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1561| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1561| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GLUTSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GLUTSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1565| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1565| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1468| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1468| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1567| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1567| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GLUTSYNIII-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GLUTSYNIII-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1568| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1568| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1546| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1546| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|CYANCAT-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|CYANCAT-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|BGALACT-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|BGALACT-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1501| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1501| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|VALSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|VALSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1466| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1466| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-1269| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-1269| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GALACTITOLCAT-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GALACTITOLCAT-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1481| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1481| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|IDNCAT-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|IDNCAT-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-4261| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-4261| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1182| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1182| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|HISTSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|HISTSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|TREDEGLOW-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|TREDEGLOW-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-2161| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-2161| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|DTDPRHAMSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|DTDPRHAMSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1506| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1506| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1306| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1306| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|ACETOACETATE-DEG-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|ACETOACETATE-DEG-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|ENTNER-DOUDOROFF-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|ENTNER-DOUDOROFF-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6614| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6614| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|DAPLYSINESYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|DAPLYSINESYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|RHAMCAT-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|RHAMCAT-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|1CMET2-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|1CMET2-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1590| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1590| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7315| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7315| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GLYCOGENSYNTH-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GLYCOGENSYNTH-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GALACTCAT-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GALACTCAT-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|DARABCATK12-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|DARABCATK12-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1485| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1485| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1338| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1338| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6543| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6543| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|ARABCAT-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|ARABCAT-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-661| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-661| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1514| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1514| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7242| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7242| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-43| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-43| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1324| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1324| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GLUCONEO-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GLUCONEO-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|XYLCAT-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|XYLCAT-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-662| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-662| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|SORBDEG-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|SORBDEG-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1303| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1303| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1492| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1492| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-301| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-301| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|GALACTMETAB-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|GALACTMETAB-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-5852| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-5852| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PLPSAL-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PLPSAL-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-321| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-321| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6608| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6608| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-4121| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-4121| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1519| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1519| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6961| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6961| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|SALVADEHYPOX-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|SALVADEHYPOX-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PYRIDOXSYN-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PYRIDOXSYN-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6617| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6617| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1591| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1591| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1497| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1497| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1507| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1507| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-6556| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-6556| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1588| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1588| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PROPIONMET-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PROPIONMET-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1295| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1295| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|RIBOSYN2-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|RIBOSYN2-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1597| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1597| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY-7195| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY-7195| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1458| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1458| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1321| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1321| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1500| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1500| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|HCAMHPDEG-PWY| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|HCAMHPDEG-PWY| :experimental-only? t :sorted? t))
# enzymes-of-pathway
# (enzymes-of-pathway '|PWY0-1336| :experimental-only? t :sorted? t)
# (with-organism (:org-id '|ECOLI|) (enzymes-of-pathway '|PWY0-1336| :experimental-only? t :sorted? t))
# [u'|NADH-DHI-CPLX|', u'|FUMARATE-REDUCTASE|']

# %%
lst = []
for pwy in ecoli.all_pathways(selector = ':all', base = True):
    lst.append(ecoli.compounds_of_pathway(pwy = pwy))
lst[-1]
# Out:
# all-pathways
# (all-pathways ::all t )
# (with-organism (:org-id '|ECOLI|) (all-pathways ::all t ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1347| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1474| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6690| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1348| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1348| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5162| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5162| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1352| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1352| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1505| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1505| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1355| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1355| ))
# compounds-of-pathway
# (compounds-of-pathway '|2PHENDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|2PHENDEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1465| ))
# compounds-of-pathway
# (compounds-of-pathway '|TRESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|TRESYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PANTO-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PANTO-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1356| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1356| ))
# compounds-of-pathway
# (compounds-of-pathway '|ETOH-ACETYLCOA-ANA-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|ETOH-ACETYLCOA-ANA-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1483| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1483| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1573| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1573| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1586| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1586| ))
# compounds-of-pathway
# (compounds-of-pathway '|GLUCONSUPER-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GLUCONSUPER-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1576| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1576| ))
# compounds-of-pathway
# (compounds-of-pathway '|GLYCEROLMETAB-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GLYCEROLMETAB-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1512| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1512| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1577| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1577| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5123| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5123| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1313| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1313| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6387| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6387| ))
# compounds-of-pathway
# (compounds-of-pathway '|PYRIDNUCSAL-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PYRIDNUCSAL-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1578| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1578| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1490| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1490| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1581| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1581| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY3O-4106| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY3O-4106| ))
# compounds-of-pathway
# (compounds-of-pathway '|KDOSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|KDOSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7761| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7761| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1582| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1582| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7971| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7971| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1534| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1534| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6952| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6952| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1518| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1518| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7184| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7184| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1584| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1584| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6038| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6038| ))
# compounds-of-pathway
# (compounds-of-pathway '|PYRIDNUCSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PYRIDNUCSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1585| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1585| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-981| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-981| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1495| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1495| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7181| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7181| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7801| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7801| ))
# compounds-of-pathway
# (compounds-of-pathway '|PYRUVDEHYD-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PYRUVDEHYD-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5509| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5509| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5350| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5350| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1559| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1559| ))
# compounds-of-pathway
# (compounds-of-pathway '|ALKANEMONOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|ALKANEMONOX-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|HOMOSER-METSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|HOMOSER-METSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6153| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6153| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1535| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1535| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7206| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7206| ))
# compounds-of-pathway
# (compounds-of-pathway '|AST-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|AST-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5340| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5340| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-823| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-823| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-541| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-541| ))
# compounds-of-pathway
# (compounds-of-pathway '|THREONINE-DEG2-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|THREONINE-DEG2-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5971| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5971| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5436| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5436| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7197| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7197| ))
# compounds-of-pathway
# (compounds-of-pathway '|THRDLCTCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|THRDLCTCAT-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1533| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1533| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5437| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5437| ))
# compounds-of-pathway
# (compounds-of-pathway '|TRNA-CHARGING-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|TRNA-CHARGING-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|LCYSDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|LCYSDEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6703| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6703| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1517| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1517| ))
# compounds-of-pathway
# (compounds-of-pathway '|GLYCLEAV-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GLYCLEAV-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|GALACTARDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GALACTARDEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7446| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7446| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7980| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7980| ))
# compounds-of-pathway
# (compounds-of-pathway '|ALADEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|ALADEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|COA-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|COA-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|HOMOSERSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|HOMOSERSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|GLYOXYLATE-BYPASS| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GLYOXYLATE-BYPASS| ))
# compounds-of-pathway
# (compounds-of-pathway '|SERDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|SERDEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6163| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6163| ))
# compounds-of-pathway
# (compounds-of-pathway '|GLUTAMINDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GLUTAMINDEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-501| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-501| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-461| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-461| ))
# compounds-of-pathway
# (compounds-of-pathway '|PROUT-PWY-I| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PROUT-PWY-I| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1275| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1275| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5901| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5901| ))
# compounds-of-pathway
# (compounds-of-pathway '|ASPARAGINE-DEG1-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|ASPARAGINE-DEG1-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|TRYPDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|TRYPDEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6164| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6164| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-522| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-522| ))
# compounds-of-pathway
# (compounds-of-pathway '|GLUTDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GLUTDEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|GALACTUROCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GALACTUROCAT-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|HEME-BIOSYNTHESIS-II| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|HEME-BIOSYNTHESIS-II| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6823| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6823| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6537| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6537| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-
ENT-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|OXIDATIVEPENT-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7193| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7193| ))
# compounds-of-pathway
# (compounds-of-pathway '|ALANINE-SYN2-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|ALANINE-SYN2-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1317| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1317| ))
# compounds-of-pathway
# (compounds-of-pathway '|LIPA-CORESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|LIPA-CORESYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1470| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1470| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1315| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1315| ))
# compounds-of-pathway
# (compounds-of-pathway '|SERSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|SERSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1280| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1280| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5698| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5698| ))
# compounds-of-pathway
# (compounds-of-pathway '|FAO-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|FAO-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7344| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7344| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7187| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7187| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1503| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1503| ))
# compounds-of-pathway
# (compounds-of-pathway '|GLUAMCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GLUAMCAT-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1264| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1264| ))
# compounds-of-pathway
# (compounds-of-pathway '|ASPARTATESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|ASPARTATESYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1221| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1221| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7343| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7343| ))
# compounds-of-pathway
# (compounds-of-pathway '|NAGLIPASYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|NAGLIPASYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1482| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1482| ))
# compounds-of-pathway
# (compounds-of-pathway '|PUTDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PUTDEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|TRPSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|TRPSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|CARNMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|CARNMET-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7335| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7335| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5837| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5837| ))
# compounds-of-pathway
# (compounds-of-pathway '|KDO-LIPASYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|KDO-LIPASYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1509| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1509| ))
# compounds-of-pathway
# (compounds-of-pathway '|GLNSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GLNSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1471| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1471| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7346| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7346| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6708| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6708| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1487| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1487| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5084| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5084| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1261| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1261| ))
# compounds-of-pathway
# (compounds-of-pathway '|ILEUSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|ILEUSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7544| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7544| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1241| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1241| ))
# compounds-of-pathway
# (compounds-of-pathway '|UDPNAGSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|UDPNAGSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|MENAQUINONESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|MENAQUINONESYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1515| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1515| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7545| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7545| ))
# compounds-of-pathway
# (compounds-of-pathway '|ASPARAGINESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|ASPARAGINESYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|FASYN-ELONG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|FASYN-ELONG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1329| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1329| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6123| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6123| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-66| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-66| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1493| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1493| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-521| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-521| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1334| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1334| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5965| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5965| ))
# compounds-of-pathway
# (compounds-of-pathway '|ASPARAGINE-BIOSYNTHESIS| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|ASPARAGINE-BIOSYNTHESIS| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-4381| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-4381| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1335| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1335| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5686| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5686| ))
# compounds-of-pathway
# (compounds-of-pathway '|MANNIDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|MANNIDEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5659| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5659| ))
# compounds-of-pathway
# (compounds-of-pathway '|PPGPPMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PPGPPMET-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1550| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1550| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1353| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1353| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5966| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5966| ))
# compounds-of-pathway
# (compounds-of-pathway '|HOMOSER-THRESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|HOMOSER-THRESYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1544| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1544| ))
# compounds-of-pathway
# (compounds-of-pathway '|NONMEVIPP-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|NONMEVIPP-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1498| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1498| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1561| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1561| ))
# compounds-of-pathway
# (compounds-of-pathway '|GLUTSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GLUTSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1565| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1565| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1468| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1468| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1567| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1567| ))
# compounds-of-pathway
# (compounds-of-pathway '|GLUTSYNIII-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GLUTSYNIII-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1568| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1568| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1546| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1546| ))
# compounds-of-pathway
# (compounds-of-pathway '|CYANCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|CYANCAT-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|BGALACT-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|BGALACT-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1501| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1501| ))
# compounds-of-pathway
# (compounds-of-pathway '|VALSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|VALSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1466| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1466| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-1269| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-1269| ))
# compounds-of-pathway
# (compounds-of-pathway '|GALACTITOLCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GALACTITOLCAT-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1481| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1481| ))
# compounds-of-pathway
# (compounds-of-pathway '|IDNCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|IDNCAT-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-4261| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-4261| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1182| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1182| ))
# compounds-of-pathway
# (compounds-of-pathway '|HISTSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|HISTSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|TREDEGLOW-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|TREDEGLOW-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-2161| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-2161| ))
# compounds-of-pathway
# (compounds-of-pathway '|DTDPRHAMSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|DTDPRHAMSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1506| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1506| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1306| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1306| ))
# compounds-of-pathway
# (compounds-of-pathway '|ACETOACETATE-DEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|ACETOACETATE-DEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|ENTNER-DOUDOROFF-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|ENTNER-DOUDOROFF-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6614| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6614| ))
# compounds-of-pathway
# (compounds-of-pathway '|DAPLYSINESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|DAPLYSINESYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|RHAMCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|RHAMCAT-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|1CMET2-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|1CMET2-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1590| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1590| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7315| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7315| ))
# compounds-of-pathway
# (compounds-of-pathway '|GLYCOGENSYNTH-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GLYCOGENSYNTH-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|GALACTCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GALACTCAT-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|DARABCATK12-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|DARABCATK12-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1485| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1485| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1338| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1338| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6543| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6543| ))
# compounds-of-pathway
# (compounds-of-pathway '|ARABCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|ARABCAT-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-661| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-661| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1514| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1514| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7242| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7242| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-43| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-43| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1324| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1324| ))
# compounds-of-pathway
# (compounds-of-pathway '|GLUCONEO-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GLUCONEO-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|XYLCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|XYLCAT-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-662| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-662| ))
# compounds-of-pathway
# (compounds-of-pathway '|SORBDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|SORBDEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1303| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1303| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1492| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1492| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-301| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-301| ))
# compounds-of-pathway
# (compounds-of-pathway '|GALACTMETAB-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|GALACTMETAB-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-5852| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-5852| ))
# compounds-of-pathway
# (compounds-of-pathway '|PLPSAL-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PLPSAL-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-321| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-321| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6608| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6608| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-4121| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-4121| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1519| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1519| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6961| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6961| ))
# compounds-of-pathway
# (compounds-of-pathway '|SALVADEHYPOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|SALVADEHYPOX-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PYRIDOXSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PYRIDOXSYN-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6617| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6617| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1591| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1591| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1497| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1497| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1507| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1507| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-6556| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-6556| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1588| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1588| ))
# compounds-of-pathway
# (compounds-of-pathway '|PROPIONMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PROPIONMET-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1295| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1295| ))
# compounds-of-pathway
# (compounds-of-pathway '|RIBOSYN2-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|RIBOSYN2-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1597| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1597| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY-7195| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY-7195| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1458| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1458| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1321| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1321| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1500| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1500| ))
# compounds-of-pathway
# (compounds-of-pathway '|HCAMHPDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|HCAMHPDEG-PWY| ))
# compounds-of-pathway
# (compounds-of-pathway '|PWY0-1336| )
# (with-organism (:org-id '|ECOLI|) (compounds-of-pathway '|PWY0-1336| ))
# [u'|FUM|',
#  u'|SUC|',
#  u'|Menaquinones|',
#  u'|Menaquinols|',
#  u'|E-|',
#  u'|PROTON|',
#  u'|NAD|',
#  u'|NADH|']

# %%
lst = []
for pwy in ecoli.all_pathways(selector = ':all', base = True):
    lst.append(ecoli.substrates_of_pathway(pwy = pwy))
lst[0]
# Out:
# all-pathways
# (all-pathways ::all t )
# (with-organism (:org-id '|ECOLI|) (all-pathways ::all t ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1347| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1474| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6690| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1348| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1348| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5162| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5162| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1352| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1352| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1505| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1505| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1355| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1355| ))
# substrates-of-pathway
# (substrates-of-pathway '|2PHENDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|2PHENDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1465| ))
# substrates-of-pathway
# (substrates-of-pathway '|TRESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|TRESYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PANTO-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PANTO-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1356| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1356| ))
# substrates-of-pathway
# (substrates-of-pathway '|ETOH-ACETYLCOA-ANA-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ETOH-ACETYLCOA-ANA-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1483| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1483| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1573| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1573| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1586| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1586| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLUCONSUPER-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLUCONSUPER-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1576| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1576| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLYCEROLMETAB-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLYCEROLMETAB-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1512| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1512| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1577| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1577| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5123| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5123| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1313| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1313| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6387| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6387| ))
# substrates-of-pathway
# (substrates-of-pathway '|PYRIDNUCSAL-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PYRIDNUCSAL-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1578| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1578| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1490| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1490| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1581| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1581| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY3O-4106| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY3O-4106| ))
# substrates-of-pathway
# (substrates-of-pathway '|KDOSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|KDOSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7761| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7761| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1582| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1582| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7971| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7971| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1534| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1534| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6952| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6952| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1518| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1518| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7184| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7184| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1584| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1584| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6038| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6038| ))
# substrates-of-pathway
# (substrates-of-pathway '|PYRIDNUCSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PYRIDNUCSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1585| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1585| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-981| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-981| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1495| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1495| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7181| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7181| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7801| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7801| ))
# substrates-of-pathway
# (substrates-of-pathway '|PYRUVDEHYD-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PYRUVDEHYD-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5509| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5509| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5350| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5350| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1559| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1559| ))
# substrates-of-pathway
# (substrates-of-pathway '|ALKANEMONOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ALKANEMONOX-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|HOMOSER-METSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|HOMOSER-METSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6153| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6153| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1535| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1535| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7206| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7206| ))
# substrates-of-pathway
# (substrates-of-pathway '|AST-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|AST-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5340| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5340| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-823| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-823| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-541| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-541| ))
# substrates-of-pathway
# (substrates-of-pathway '|THREONINE-DEG2-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|THREONINE-DEG2-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5971| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5971| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5436| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5436| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7197| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7197| ))
# substrates-of-pathway
# (substrates-of-pathway '|THRDLCTCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|THRDLCTCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1533| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1533| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5437| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5437| ))
# substrates-of-pathway
# (substrates-of-pathway '|TRNA-CHARGING-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|TRNA-CHARGING-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|LCYSDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|LCYSDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6703| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6703| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1517| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1517| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLYCLEAV-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLYCLEAV-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|GALACTARDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GALACTARDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7446| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7446| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7980| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7980| ))
# substrates-of-pathway
# (substrates-of-pathway '|ALADEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ALADEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|COA-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|COA-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|HOMOSERSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|HOMOSERSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLYOXYLATE-BYPASS| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLYOXYLATE-BYPASS| ))
# substrates-of-pathway
# (substrates-of-pathway '|SERDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|SERDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6163| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6163| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLUTAMINDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLUTAMINDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-501| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-501| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-461| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-461| ))
# substrates-of-pathway
# (substrates-of-pathway '|PROUT-PWY-I| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PROUT-PWY-I| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1275| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1275| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5901| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5901| ))
# substrates-of-pathway
# (substrates-of-pathway '|ASPARAGINE-DEG1-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ASPARAGINE-DEG1-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|TRYPDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|TRYPDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6164| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6164| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-522| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-522| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLUTDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLUTDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|GALACTUROCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GALACTUROCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|HEME-BIOSYNTHESIS-II| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|HEME-BIOSYNTHESIS-II| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6823| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6823| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6537| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6537| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6535| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6535| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7220| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7220| ))
# substrates-of-pathway
# (substrates-of-pathway '|HEMESYN2-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|HEMESYN2-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5755| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5755| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7222| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7222| ))
# substrates-of-pathway
# (substrates-of-pathway '|NADPHOS-DEPHOS-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|NADPHOS-DEPHOS-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7805| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7805| ))
# substrates-of-pathway
# (substrates-of-pathway '|P2-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|P2-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5973| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5973| ))
# substrates-of-pathway
# (substrates-of-pathway '|FERMENTATION-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|FERMENTATION-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-1801| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-1801| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLUCARDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLUCARDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5964| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5964| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7884| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7884| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6012| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6012| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7176| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7176| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5667| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5667| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6476| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6476| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1433| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1433| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5785| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5785| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1319| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1319| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1312| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1312| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1479| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1479| ))
# substrates-of-pathway
# (substrates-of-pathway '|SAM-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|SAM-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7219| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7219| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6268| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6268| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5669| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5669| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLYCOCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLYCOCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLYOXDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLYOXDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7892| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7892| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5783| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5783| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7221| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7221| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6894| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6894| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1545| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1545| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLYCOLATEMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLYCOLATEMET-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7247| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7247| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1587| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1587| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLUTORN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLUTORN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1296| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1296| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6605| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6605| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6890| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6890| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5668| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5668| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7179| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7179| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6700| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6700| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5155| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5155| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6019| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6019| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6611| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6611| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6892| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6892| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5194| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5194| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1391| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1391| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1554| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1554| ))
# substrates-of-pathway
# (substrates-of-pathway '|PROSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PROSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6609| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6609| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6910| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6910| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLUTATHIONESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLUTATHIONESYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-40| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-40| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5484| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5484| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-4621| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-4621| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-901| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-901| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-46| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-46| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6620| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6620| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6519| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6519| ))
# substrates-of-pathway
# (substrates-of-pathway '|SALVPURINE2-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|SALVPURINE2-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|BETSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|BETSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5453| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5453| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLUT-REDOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLUT-REDOX-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7870| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7870| ))
# substrates-of-pathway
# (substrates-of-pathway '|BSUBPOLYAMSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|BSUBPOLYAMSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6618| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6618| ))
# substrates-of-pathway
# (substrates-of-pathway '|THIOREDOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|THIOREDOX-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|CYSTSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|CYSTSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5386| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5386| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6282| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6282| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5188| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5188| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6121| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6121| ))
# substrates-of-pathway
# (substrates-of-pathway '|TYRSYN| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|TYRSYN| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-862| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-862| ))
# substrates-of-pathway
# (substrates-of-pathway '|TCA| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|TCA| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6122| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6122| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1305| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1305| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLUCOSE1PMETAB-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLUCOSE1PMETAB-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLYCOLYSIS| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLYCOLYSIS| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLYSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLYSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7180| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7180| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1477| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1477| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7183| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7183| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1309| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1309| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1299| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1299| ))
# substrates-of-pathway
# (substrates-of-pathway '|NONOXIPENT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|NONOXIPENT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|LEUSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|LEUSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|RIBOKIN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|RIBOKIN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7205| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7205| ))
# substrates-of-pathway
# (substrates-of-pathway '|FUCCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|FUCCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|DETOX1-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|DETOX1-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PHESYN| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PHESYN| ))
# substrates-of-pathway
# (substrates-of-pathway '|MANNCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|MANNCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6147| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6147| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1337| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1337| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-181| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-181| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1021| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1021| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1301| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1301| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-44| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-44| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-163| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-163| ))
# substrates-of-pathway
# (substrates-of-pathway '|NRI-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|NRI-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-42| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-42| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1569| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1569| ))
# substrates-of-pathway
# (substrates-of-pathway '|LYXMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|LYXMET-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|ALANINE-VALINESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ALANINE-VALINESYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1300| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1300| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1499| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1499| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1314| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1314| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1527| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1527| ))
# substrates-of-pathway
# (substrates-of-pathway '|OXIDATIVEPENT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|OXIDATIVEPENT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7193| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7193| ))
# substrates-of-pathway
# (substrates-of-pathway '|ALANINE-SYN2-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ALANINE-SYN2-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1317| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1317| ))
# substrates-of-pathway
# (substrates-of-pathway '|LIPA-CORESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|LIPA-CORESYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1470| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1470| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1315| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1315| ))
# substrates-of-pathway
# (substrates-of-pathway '|SERSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|SERSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1280| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1280| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5698| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5698| ))
# substrates-of-pathway
# (substrates-of-pathway '|FAO-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|FAO-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7344| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7344| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7187| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7187| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1503| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1503| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLUAMCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLUAMCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1264| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1264| ))
# substrates-of-pathway
# (substrates-of-pathway '|ASPARTATESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ASPARTATESYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1221| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1221| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7343| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7343| ))
# substrates-of-pathway
# (substrates-of-pathway '|NAGLIPASYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|NAGLIPASYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1482| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1482| ))
# substrates-of-pathway
# (substrates-of-pathway '|PUTDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PUTDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|TRPSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|TRPSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|CARNMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|CARNMET-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7335| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7335| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5837| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5837| ))
# substrates-of-pathway
# (substrates-of-pathway '|KDO-LIPASYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|KDO-LIPASYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1509| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1509| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLNSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLNSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1471| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1471| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7346| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7346| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6708| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6708| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1487| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1487| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5084| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5084| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1261| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1261| ))
# substrates-of-pathway
# (substrates-of-pathway '|ILEUSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ILEUSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7544| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7544| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1241| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1241| ))
# substrates-of-pathway
# (substrates-of-pathway '|UDPNAGSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|UDPNAGSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|MENAQUINONESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|MENAQUINONESYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1515| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1515| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7545| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7545| ))
# substrates-of-pathway
# (substrates-of-pathway '|ASPARAGINESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ASPARAGINESYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|FASYN-ELONG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|FASYN-ELONG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1329| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1329| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6123| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6123| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-66| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-66| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1493| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1493| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-521| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-521| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1334| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1334| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5965| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5965| ))
# substrates-of-pathway
# (substrates-of-pathway '|ASPARAGINE-BIOSYNTHESIS| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ASPARAGINE-BIOSYNTHESIS| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-4381| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-4381| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1335| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1335| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5686| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5686| ))
# substrates-of-pathway
# (substrates-of-pathway '|MANNIDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|MANNIDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5659| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5659| ))
# substrates-of-pathway
# (substrates-of-pathway '|PPGPPMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PPGPPMET-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1550| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1550| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1353| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1353| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5966| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5966| ))
# substrates-of-pathway
# (substrates-of-pathway '|HOMOSER-THRESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|HOMOSER-THRESYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1544| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1544| ))
# substrates-of-pathway
# (substrates-of-pathway '|NONMEVIPP-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|NONMEVIPP-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1498| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1498| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1561| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1561| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLUTSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLUTSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1565| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1565| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1468| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1468| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1567| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1567| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLUTSYNIII-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLUTSYNIII-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1568| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1568| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1546| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1546| ))
# substrates-of-pathway
# (substrates-of-pathway '|CYANCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|CYANCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|BGALACT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|BGALACT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1501| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1501| ))
# substrates-of-pathway
# (substrates-of-pathway '|VALSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|VALSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1466| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1466| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-1269| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-1269| ))
# substrates-of-pathway
# (substrates-of-pathway '|GALACTITOLCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GALACTITOLCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1481| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1481| ))
# substrates-of-pathway
# (substrates-of-pathway '|IDNCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|IDNCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-4261| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-4261| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1182| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1182| ))
# substrates-of-pathway
# (substrates-of-pathway '|HISTSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|HISTSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|TREDEGLOW-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|TREDEGLOW-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-2161| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-2161| ))
# substrates-of-pathway
# (substrates-of-pathway '|DTDPRHAMSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|DTDPRHAMSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1506| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1506| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1306| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1306| ))
# substrates-of-pathway
# (substrates-of-pathway '|ACETOACETATE-DEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ACETOACETATE-DEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|ENTNER-DOUDOROFF-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ENTNER-DOUDOROFF-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6614| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6614| ))
# substrates-of-pathway
# (substrates-of-pathway '|DAPLYSINESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|DAPLYSINESYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|RHAMCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|RHAMCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|1CMET2-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|1CMET2-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1590| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1590| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7315| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7315| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLYCOGENSYNTH-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLYCOGENSYNTH-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|GALACTCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GALACTCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|DARABCATK12-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|DARABCATK12-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1485| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1485| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1338| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1338| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6543| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6543| ))
# substrates-of-pathway
# (substrates-of-pathway '|ARABCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|ARABCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-661| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-661| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1514| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1514| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7242| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7242| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-43| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-43| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1324| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1324| ))
# substrates-of-pathway
# (substrates-of-pathway '|GLUCONEO-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GLUCONEO-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|XYLCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|XYLCAT-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-662| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-662| ))
# substrates-of-pathway
# (substrates-of-pathway '|SORBDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|SORBDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1303| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1303| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1492| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1492| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-301| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-301| ))
# substrates-of-pathway
# (substrates-of-pathway '|GALACTMETAB-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|GALACTMETAB-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-5852| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-5852| ))
# substrates-of-pathway
# (substrates-of-pathway '|PLPSAL-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PLPSAL-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-321| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-321| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6608| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6608| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-4121| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-4121| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1519| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1519| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6961| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6961| ))
# substrates-of-pathway
# (substrates-of-pathway '|SALVADEHYPOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|SALVADEHYPOX-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PYRIDOXSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PYRIDOXSYN-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6617| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6617| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1591| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1591| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1497| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1497| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1507| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1507| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-6556| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-6556| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1588| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1588| ))
# substrates-of-pathway
# (substrates-of-pathway '|PROPIONMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PROPIONMET-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1295| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1295| ))
# substrates-of-pathway
# (substrates-of-pathway '|RIBOSYN2-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|RIBOSYN2-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1597| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1597| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY-7195| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY-7195| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1458| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1458| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1321| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1321| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1500| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1500| ))
# substrates-of-pathway
# (substrates-of-pathway '|HCAMHPDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|HCAMHPDEG-PWY| ))
# substrates-of-pathway
# (substrates-of-pathway '|PWY0-1336| )
# (with-organism (:org-id '|ECOLI|) (substrates-of-pathway '|PWY0-1336| ))
# [[u'|NADH|',
#   u'|Menaquinones|',
#   u'|Menaquinols|',
#   u'|PROTON|',
#   u'|TRIMETHYLAMINE-N-O|'],
#  [u'|TRIMETHYLAMINE-N-O|', u'|NADH|'],
#  [u'|NAD|',
#   u'|Menaquinols|',
#   u'|PROTON|',
#   u'|TRIMETHYLAMINE|',
#   u'|WATER|',
#   u'|Menaquinones|'],
#  [u'|WATER|', u'|TRIMETHYLAMINE|', u'|NAD|']]

# %%
lst = []
for pwy in ecoli.all_pathways(selector = ':all', base = True):
    lst.append(ecoli.variants_of_pathway(pwy = pwy))
lst[-10:]
# Out:
# all-pathways
# (all-pathways ::all t )
# (with-organism (:org-id '|ECOLI|) (all-pathways ::all t ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1347| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1474| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6690| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1348| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1348| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5162| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5162| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1352| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1352| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1505| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1505| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1355| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1355| ))
# variants-of-pathway
# (variants-of-pathway '|2PHENDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|2PHENDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1465| ))
# variants-of-pathway
# (variants-of-pathway '|TRESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|TRESYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PANTO-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PANTO-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1356| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1356| ))
# variants-of-pathway
# (variants-of-pathway '|ETOH-ACETYLCOA-ANA-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ETOH-ACETYLCOA-ANA-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1483| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1483| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1573| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1573| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1586| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1586| ))
# variants-of-pathway
# (variants-of-pathway '|GLUCONSUPER-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLUCONSUPER-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1576| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1576| ))
# variants-of-pathway
# (variants-of-pathway '|GLYCEROLMETAB-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLYCEROLMETAB-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1512| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1512| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1577| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1577| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5123| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5123| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1313| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1313| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6387| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6387| ))
# variants-of-pathway
# (variants-of-pathway '|PYRIDNUCSAL-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PYRIDNUCSAL-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1578| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1578| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1490| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1490| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1581| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1581| ))
# variants-of-pathway
# (variants-of-pathway '|PWY3O-4106| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY3O-4106| ))
# variants-of-pathway
# (variants-of-pathway '|KDOSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|KDOSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7761| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7761| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1582| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1582| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7971| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7971| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1534| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1534| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6952| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6952| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1518| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1518| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7184| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7184| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1584| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1584| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6038| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6038| ))
# variants-of-pathway
# (variants-of-pathway '|PYRIDNUCSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PYRIDNUCSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1585| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1585| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-981| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-981| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1495| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1495| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7181| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7181| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7801| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7801| ))
# variants-of-pathway
# (variants-of-pathway '|PYRUVDEHYD-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PYRUVDEHYD-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5509| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5509| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5350| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5350| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1559| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1559| ))
# variants-of-pathway
# (variants-of-pathway '|ALKANEMONOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ALKANEMONOX-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|HOMOSER-METSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|HOMOSER-METSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6153| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6153| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1535| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1535| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7206| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7206| ))
# variants-of-pathway
# (variants-of-pathway '|AST-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|AST-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5340| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5340| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-823| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-823| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-541| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-541| ))
# variants-of-pathway
# (variants-of-pathway '|THREONINE-DEG2-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|THREONINE-DEG2-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5971| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5971| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5436| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5436| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7197| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7197| ))
# variants-of-pathway
# (variants-of-pathway '|THRDLCTCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|THRDLCTCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1533| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1533| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5437| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5437| ))
# variants-of-pathway
# (variants-of-pathway '|TRNA-CHARGING-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|TRNA-CHARGING-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|LCYSDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|LCYSDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6703| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6703| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1517| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1517| ))
# variants-of-pathway
# (variants-of-pathway '|GLYCLEAV-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLYCLEAV-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|GALACTARDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GALACTARDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7446| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7446| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7980| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7980| ))
# variants-of-pathway
# (variants-of-pathway '|ALADEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ALADEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|COA-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|COA-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|HOMOSERSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|HOMOSERSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|GLYOXYLATE-BYPASS| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLYOXYLATE-BYPASS| ))
# variants-of-pathway
# (variants-of-pathway '|SERDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|SERDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6163| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6163| ))
# variants-of-pathway
# (variants-of-pathway '|GLUTAMINDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLUTAMINDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-501| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-501| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-461| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-461| ))
# variants-of-pathway
# (variants-of-pathway '|PROUT-PWY-I| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PROUT-PWY-I| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1275| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1275| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5901| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5901| ))
# variants-of-pathway
# (variants-of-pathway '|ASPARAGINE-DEG1-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ASPARAGINE-DEG1-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|TRYPDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|TRYPDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6164| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6164| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-522| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-522| ))
# variants-of-pathway
# (variants-of-pathway '|GLUTDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLUTDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|GALACTUROCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GALACTUROCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|HEME-BIOSYNTHESIS-II| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|HEME-BIOSYNTHESIS-II| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6823| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6823| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6537| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6537| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6535| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6535| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7220| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7220| ))
# variants-of-pathway
# (variants-of-pathway '|HEMESYN2-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|HEMESYN2-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5755| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5755| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7222| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7222| ))
# variants-of-pathway
# (variants-of-pathway '|NADPHOS-DEPHOS-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|NADPHOS-DEPHOS-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7805| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7805| ))
# variants-of-pathway
# (variants-of-pathway '|P2-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|P2-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5973| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5973| ))
# variants-of-pathway
# (variants-of-pathway '|FERMENTATION-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|FERMENTATION-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-1801| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-1801| ))
# variants-of-pathway
# (variants-of-pathway '|GLUCARDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLUCARDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5964| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5964| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7884| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7884| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6012| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6012| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7176| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7176| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5667| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5667| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6476| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6476| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1433| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1433| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5785| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5785| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1319| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1319| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1312| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1312| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1479| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1479| ))
# variants-of-pathway
# (variants-of-pathway '|SAM-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|SAM-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7219| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7219| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6268| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6268| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5669| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5669| ))
# variants-of-pathway
# (variants-of-pathway '|GLYCOCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLYCOCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|GLYOXDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLYOXDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7892| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7892| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5783| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5783| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7221| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7221| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6894| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6894| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1545| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1545| ))
# variants-of-pathway
# (variants-of-pathway '|GLYCOLATEMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLYCOLATEMET-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7247| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7247| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1587| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1587| ))
# variants-of-pathway
# (variants-of-pathway '|GLUTORN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLUTORN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1296| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1296| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6605| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6605| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6890| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6890| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5668| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5668| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7179| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7179| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6700| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6700| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5155| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5155| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6019| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6019| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6611| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6611| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6892| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6892| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5194| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5194| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1391| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1391| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1554| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1554| ))
# variants-of-pathway
# (variants-of-pathway '|PROSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PROSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6609| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6609| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6910| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6910| ))
# variants-of-pathway
# (variants-of-pathway '|GLUTATHIONESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLUTATHIONESYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-40| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-40| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5484| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5484| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-4621| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-4621| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-901| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-901| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-46| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-46| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6620| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6620| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6519| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6519| ))
# variants-of-pathway
# (variants-of-pathway '|SALVPURINE2-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|SALVPURINE2-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|BETSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|BETSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5453| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5453| ))
# variants-of-pathway
# (variants-of-pathway '|GLUT-REDOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLUT-REDOX-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7870| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7870| ))
# variants-of-pathway
# (variants-of-pathway '|BSUBPOLYAMSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|BSUBPOLYAMSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6618| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6618| ))
# variants-of-pathway
# (variants-of-pathway '|THIOREDOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|THIOREDOX-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|CYSTSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|CYSTSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5386| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5386| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6282| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6282| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5188| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5188| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6121| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6121| ))
# variants-of-pathway
# (variants-of-pathway '|TYRSYN| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|TYRSYN| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-862| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-862| ))
# variants-of-pathway
# (variants-of-pathway '|TCA| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|TCA| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6122| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6122| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1305| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1305| ))
# variants-of-pathway
# (variants-of-pathway '|GLUCOSE1PMETAB-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLUCOSE1PMETAB-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|GLYCOLYSIS| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLYCOLYSIS| ))
# variants-of-pathway
# (variants-of-pathway '|GLYSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLYSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7180| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7180| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1477| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1477| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7183| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7183| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1309| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1309| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1299| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1299| ))
# variants-of-pathway
# (variants-of-pathway '|NONOXIPENT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|NONOXIPENT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|LEUSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|LEUSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|RIBOKIN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|RIBOKIN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7205| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7205| ))
# variants-of-pathway
# (variants-of-pathway '|FUCCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|FUCCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|DETOX1-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|DETOX1-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PHESYN| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PHESYN| ))
# variants-of-pathway
# (variants-of-pathway '|MANNCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|MANNCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6147| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6147| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1337| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1337| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-181| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-181| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1021| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1021| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1301| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1301| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-44| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-44| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-163| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-163| ))
# variants-of-pathway
# (variants-of-pathway '|NRI-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|NRI-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-42| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-42| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1569| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1569| ))
# variants-of-pathway
# (variants-of-pathway '|LYXMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|LYXMET-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|ALANINE-VALINESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ALANINE-VALINESYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1300| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1300| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1499| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1499| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1314| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1314| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1527| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1527| ))
# variants-of-pathway
# (variants-of-pathway '|OXIDATIVEPENT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|OXIDATIVEPENT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7193| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7193| ))
# variants-of-pathway
# (variants-of-pathway '|ALANINE-SYN2-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ALANINE-SYN2-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1317| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1317| ))
# variants-of-pathway
# (variants-of-pathway '|LIPA-CORESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|LIPA-CORESYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1470| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1470| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1315| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1315| ))
# variants-of-pathway
# (variants-of-pathway '|SERSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|SERSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1280| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1280| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5698| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5698| ))
# variants-of-pathway
# (variants-of-pathway '|FAO-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|FAO-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7344| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7344| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7187| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7187| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1503| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1503| ))
# variants-of-pathway
# (variants-of-pathway '|GLUAMCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLUAMCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1264| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1264| ))
# variants-of-pathway
# (variants-of-pathway '|ASPARTATESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ASPARTATESYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1221| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1221| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7343| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7343| ))
# variants-of-pathway
# (variants-of-pathway '|NAGLIPASYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|NAGLIPASYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1482| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1482| ))
# variants-of-pathway
# (variants-of-pathway '|PUTDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PUTDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|TRPSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|TRPSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|CARNMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|CARNMET-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7335| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7335| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5837| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5837| ))
# variants-of-pathway
# (variants-of-pathway '|KDO-LIPASYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|KDO-LIPASYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1509| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1509| ))
# variants-of-pathway
# (variants-of-pathway '|GLNSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLNSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1471| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1471| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7346| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7346| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6708| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6708| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1487| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1487| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5084| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5084| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1261| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1261| ))
# variants-of-pathway
# (variants-of-pathway '|ILEUSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ILEUSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7544| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7544| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1241| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1241| ))
# variants-of-pathway
# (variants-of-pathway '|UDPNAGSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|UDPNAGSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|MENAQUINONESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|MENAQUINONESYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1515| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1515| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7545| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7545| ))
# variants-of-pathway
# (variants-of-pathway '|ASPARAGINESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ASPARAGINESYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|FASYN-ELONG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|FASYN-ELONG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1329| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1329| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6123| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6123| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-66| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-66| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1493| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1493| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-521| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-521| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1334| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1334| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5965| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5965| ))
# variants-of-pathway
# (variants-of-pathway '|ASPARAGINE-BIOSYNTHESIS| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ASPARAGINE-BIOSYNTHESIS| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-4381| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-4381| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1335| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1335| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5686| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5686| ))
# variants-of-pathway
# (variants-of-pathway '|MANNIDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|MANNIDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5659| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5659| ))
# variants-of-pathway
# (variants-of-pathway '|PPGPPMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PPGPPMET-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1550| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1550| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1353| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1353| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5966| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5966| ))
# variants-of-pathway
# (variants-of-pathway '|HOMOSER-THRESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|HOMOSER-THRESYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1544| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1544| ))
# variants-of-pathway
# (variants-of-pathway '|NONMEVIPP-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|NONMEVIPP-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1498| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1498| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1561| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1561| ))
# variants-of-pathway
# (variants-of-pathway '|GLUTSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLUTSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1565| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1565| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1468| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1468| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1567| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1567| ))
# variants-of-pathway
# (variants-of-pathway '|GLUTSYNIII-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLUTSYNIII-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1568| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1568| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1546| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1546| ))
# variants-of-pathway
# (variants-of-pathway '|CYANCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|CYANCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|BGALACT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|BGALACT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1501| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1501| ))
# variants-of-pathway
# (variants-of-pathway '|VALSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|VALSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1466| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1466| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-1269| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-1269| ))
# variants-of-pathway
# (variants-of-pathway '|GALACTITOLCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GALACTITOLCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1481| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1481| ))
# variants-of-pathway
# (variants-of-pathway '|IDNCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|IDNCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-4261| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-4261| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1182| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1182| ))
# variants-of-pathway
# (variants-of-pathway '|HISTSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|HISTSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|TREDEGLOW-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|TREDEGLOW-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-2161| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-2161| ))
# variants-of-pathway
# (variants-of-pathway '|DTDPRHAMSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|DTDPRHAMSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1506| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1506| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1306| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1306| ))
# variants-of-pathway
# (variants-of-pathway '|ACETOACETATE-DEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ACETOACETATE-DEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|ENTNER-DOUDOROFF-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ENTNER-DOUDOROFF-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6614| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6614| ))
# variants-of-pathway
# (variants-of-pathway '|DAPLYSINESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|DAPLYSINESYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|RHAMCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|RHAMCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|1CMET2-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|1CMET2-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1590| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1590| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7315| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7315| ))
# variants-of-pathway
# (variants-of-pathway '|GLYCOGENSYNTH-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLYCOGENSYNTH-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|GALACTCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GALACTCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|DARABCATK12-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|DARABCATK12-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1485| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1485| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1338| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1338| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6543| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6543| ))
# variants-of-pathway
# (variants-of-pathway '|ARABCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|ARABCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-661| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-661| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1514| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1514| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7242| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7242| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-43| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-43| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1324| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1324| ))
# variants-of-pathway
# (variants-of-pathway '|GLUCONEO-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GLUCONEO-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|XYLCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|XYLCAT-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-662| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-662| ))
# variants-of-pathway
# (variants-of-pathway '|SORBDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|SORBDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1303| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1303| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1492| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1492| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-301| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-301| ))
# variants-of-pathway
# (variants-of-pathway '|GALACTMETAB-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|GALACTMETAB-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-5852| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-5852| ))
# variants-of-pathway
# (variants-of-pathway '|PLPSAL-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PLPSAL-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-321| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-321| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6608| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6608| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-4121| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-4121| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1519| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1519| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6961| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6961| ))
# variants-of-pathway
# (variants-of-pathway '|SALVADEHYPOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|SALVADEHYPOX-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PYRIDOXSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PYRIDOXSYN-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6617| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6617| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1591| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1591| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1497| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1497| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1507| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1507| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-6556| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-6556| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1588| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1588| ))
# variants-of-pathway
# (variants-of-pathway '|PROPIONMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PROPIONMET-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1295| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1295| ))
# variants-of-pathway
# (variants-of-pathway '|RIBOSYN2-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|RIBOSYN2-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1597| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1597| ))
# variants-of-pathway
# (variants-of-pathway '|PWY-7195| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY-7195| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1458| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1458| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1321| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1321| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1500| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1500| ))
# variants-of-pathway
# (variants-of-pathway '|HCAMHPDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|HCAMHPDEG-PWY| ))
# variants-of-pathway
# (variants-of-pathway '|PWY0-1336| )
# (with-organism (:org-id '|ECOLI|) (variants-of-pathway '|PWY0-1336| ))
# [[],
#  [u'|PWY-7195|', u'|PWY-6556|'],
#  [u'|PWY0-1597|'],
#  [u'|RIBOSYN2-PWY|'],
#  [u'|PWY0-1295|', u'|PWY-6556|'],
#  [],
#  [u'|PWY0-1584|', u'|PWY0-1581|', u'|PWY0-1573|', u'|PWY0-1352|'],
#  [],
#  [],
#  []]

# %%
"""
pwy
An instance of the class |Pathways|, which is not a super-pathway (i.e., does 
not have any entries in its 'sub‑pathways slot). 
rxn-list
Optional The list of reactions to use as the starting list of connected 
component clusters. Defaults to (get‑slot‑values pwy 'reaction‑list).

pred-list
Optional The list of reaction predecessors to iterate from in order to cluster 
the reactions in rxn‑list. Defaults to (get‑slot‑values pwy 'predecessors).
"""

lst = []
for pwy in ecoli.all_pathways(selector = ':all', base = True):
    lst.append(ecoli.pathway_components(pwy = pwy))
lst[0]
# Out:
# all-pathways
# (all-pathways ::all t )
# (with-organism (:org-id '|ECOLI|) (all-pathways ::all t ))
# pathway-components
# (pathway-components '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1347| ))
# pathway-components
# (pathway-components '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1474| ))
# pathway-components
# (pathway-components '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6690| ))
# pathway-components
# (pathway-components '|PWY0-1348| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1348| ))
# pathway-components
# (pathway-components '|PWY-5162| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5162| ))
# pathway-components
# (pathway-components '|PWY0-1352| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1352| ))
# pathway-components
# (pathway-components '|PWY0-1505| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1505| ))
# pathway-components
# (pathway-components '|PWY0-1355| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1355| ))
# pathway-components
# (pathway-components '|2PHENDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|2PHENDEG-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1465| ))
# pathway-components
# (pathway-components '|TRESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|TRESYN-PWY| ))
# pathway-components
# (pathway-components '|PANTO-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PANTO-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1356| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1356| ))
# pathway-components
# (pathway-components '|ETOH-ACETYLCOA-ANA-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ETOH-ACETYLCOA-ANA-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1483| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1483| ))
# pathway-components
# (pathway-components '|PWY0-1573| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1573| ))
# pathway-components
# (pathway-components '|PWY0-1586| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1586| ))
# pathway-components
# (pathway-components '|GLUCONSUPER-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLUCONSUPER-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1576| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1576| ))
# pathway-components
# (pathway-components '|GLYCEROLMETAB-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLYCEROLMETAB-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1512| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1512| ))
# pathway-components
# (pathway-components '|PWY0-1577| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1577| ))
# pathway-components
# (pathway-components '|PWY-5123| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5123| ))
# pathway-components
# (pathway-components '|PWY0-1313| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1313| ))
# pathway-components
# (pathway-components '|PWY-6387| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6387| ))
# pathway-components
# (pathway-components '|PYRIDNUCSAL-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PYRIDNUCSAL-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1578| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1578| ))
# pathway-components
# (pathway-components '|PWY0-1490| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1490| ))
# pathway-components
# (pathway-components '|PWY0-1581| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1581| ))
# pathway-components
# (pathway-components '|PWY3O-4106| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY3O-4106| ))
# pathway-components
# (pathway-components '|KDOSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|KDOSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY-7761| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7761| ))
# pathway-components
# (pathway-components '|PWY0-1582| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1582| ))
# pathway-components
# (pathway-components '|PWY-7971| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7971| ))
# pathway-components
# (pathway-components '|PWY0-1534| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1534| ))
# pathway-components
# (pathway-components '|PWY-6952| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6952| ))
# pathway-components
# (pathway-components '|PWY0-1518| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1518| ))
# pathway-components
# (pathway-components '|PWY-7184| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7184| ))
# pathway-components
# (pathway-components '|PWY0-1584| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1584| ))
# pathway-components
# (pathway-components '|PWY-6038| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6038| ))
# pathway-components
# (pathway-components '|PYRIDNUCSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PYRIDNUCSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1585| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1585| ))
# pathway-components
# (pathway-components '|PWY0-981| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-981| ))
# pathway-components
# (pathway-components '|PWY0-1495| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1495| ))
# pathway-components
# (pathway-components '|PWY-7181| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7181| ))
# pathway-components
# (pathway-components '|PWY-7801| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7801| ))
# pathway-components
# (pathway-components '|PYRUVDEHYD-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PYRUVDEHYD-PWY| ))
# pathway-components
# (pathway-components '|PWY-5509| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5509| ))
# pathway-components
# (pathway-components '|PWY-5350| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5350| ))
# pathway-components
# (pathway-components '|PWY0-1559| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1559| ))
# pathway-components
# (pathway-components '|ALKANEMONOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ALKANEMONOX-PWY| ))
# pathway-components
# (pathway-components '|HOMOSER-METSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|HOMOSER-METSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY-6153| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6153| ))
# pathway-components
# (pathway-components '|PWY0-1535| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1535| ))
# pathway-components
# (pathway-components '|PWY-7206| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7206| ))
# pathway-components
# (pathway-components '|AST-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|AST-PWY| ))
# pathway-components
# (pathway-components '|PWY-5340| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5340| ))
# pathway-components
# (pathway-components '|PWY0-823| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-823| ))
# pathway-components
# (pathway-components '|PWY0-541| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-541| ))
# pathway-components
# (pathway-components '|THREONINE-DEG2-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|THREONINE-DEG2-PWY| ))
# pathway-components
# (pathway-components '|PWY-5971| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5971| ))
# pathway-components
# (pathway-components '|PWY-5436| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5436| ))
# pathway-components
# (pathway-components '|PWY-7197| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7197| ))
# pathway-components
# (pathway-components '|THRDLCTCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|THRDLCTCAT-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1533| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1533| ))
# pathway-components
# (pathway-components '|PWY-5437| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5437| ))
# pathway-components
# (pathway-components '|TRNA-CHARGING-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|TRNA-CHARGING-PWY| ))
# pathway-components
# (pathway-components '|LCYSDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|LCYSDEG-PWY| ))
# pathway-components
# (pathway-components '|PWY-6703| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6703| ))
# pathway-components
# (pathway-components '|PWY0-1517| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1517| ))
# pathway-components
# (pathway-components '|GLYCLEAV-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLYCLEAV-PWY| ))
# pathway-components
# (pathway-components '|GALACTARDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GALACTARDEG-PWY| ))
# pathway-components
# (pathway-components '|PWY-7446| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7446| ))
# pathway-components
# (pathway-components '|PWY-7980| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7980| ))
# pathway-components
# (pathway-components '|ALADEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ALADEG-PWY| ))
# pathway-components
# (pathway-components '|COA-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|COA-PWY| ))
# pathway-components
# (pathway-components '|HOMOSERSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|HOMOSERSYN-PWY| ))
# pathway-components
# (pathway-components '|GLYOXYLATE-BYPASS| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLYOXYLATE-BYPASS| ))
# pathway-components
# (pathway-components '|SERDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|SERDEG-PWY| ))
# pathway-components
# (pathway-components '|PWY-6163| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6163| ))
# pathway-components
# (pathway-components '|GLUTAMINDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLUTAMINDEG-PWY| ))
# pathway-components
# (pathway-components '|PWY0-501| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-501| ))
# pathway-components
# (pathway-components '|PWY0-461| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-461| ))
# pathway-components
# (pathway-components '|PROUT-PWY-I| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PROUT-PWY-I| ))
# pathway-components
# (pathway-components '|PWY0-1275| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1275| ))
# pathway-components
# (pathway-components '|PWY-5901| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5901| ))
# pathway-components
# (pathway-components '|ASPARAGINE-DEG1-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ASPARAGINE-DEG1-PWY| ))
# pathway-components
# (pathway-components '|TRYPDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|TRYPDEG-PWY| ))
# pathway-components
# (pathway-components '|PWY-6164| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6164| ))
# pathway-components
# (pathway-components '|PWY0-522| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-522| ))
# pathway-components
# (pathway-components '|GLUTDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLUTDEG-PWY| ))
# pathway-components
# (pathway-components '|GALACTUROCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GALACTUROCAT-PWY| ))
# pathway-components
# (pathway-components '|HEME-BIOSYNTHESIS-II| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|HEME-BIOSYNTHESIS-II| ))
# pathway-components
# (pathway-components '|PWY-6823| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6823| ))
# pathway-components
# (pathway-components '|PWY-6537| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6537| ))
# pathway-components
# (pathway-components '|PWY-6535| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6535| ))
# pathway-components
# (pathway-components '|PWY-7220| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7220| ))
# pathway-components
# (pathway-components '|HEMESYN2-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|HEMESYN2-PWY| ))
# pathway-components
# (pathway-components '|PWY-5755| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5755| ))
# pathway-components
# (pathway-components '|PWY-7222| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7222| ))
# pathway-components
# (pathway-components '|NADPHOS-DEPHOS-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|NADPHOS-DEPHOS-PWY| ))
# pathway-components
# (pathway-components '|PWY-7805| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7805| ))
# pathway-components
# (pathway-components '|P2-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|P2-PWY| ))
# pathway-components
# (pathway-components '|PWY-5973| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5973| ))
# pathway-components
# (pathway-components '|FERMENTATION-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|FERMENTATION-PWY| ))
# pathway-components
# (pathway-components '|PWY-1801| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-1801| ))
# pathway-components
# (pathway-components '|GLUCARDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLUCARDEG-PWY| ))
# pathway-components
# (pathway-components '|PWY-5964| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5964| ))
# pathway-components
# (pathway-components '|PWY-7884| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7884| ))
# pathway-components
# (pathway-components '|PWY-6012| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6012| ))
# pathway-components
# (pathway-components '|PWY-7176| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7176| ))
# pathway-components
# (pathway-components '|PWY-5667| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5667| ))
# pathway-components
# (pathway-components '|PWY-6476| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6476| ))
# pathway-components
# (pathway-components '|PWY0-1433| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1433| ))
# pathway-components
# (pathway-components '|PWY-5785| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5785| ))
# pathway-components
# (pathway-components '|PWY0-1319| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1319| ))
# pathway-components
# (pathway-components '|PWY0-1312| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1312| ))
# pathway-components
# (pathway-components '|PWY0-1479| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1479| ))
# pathway-components
# (pathway-components '|SAM-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|SAM-PWY| ))
# pathway-components
# (pathway-components '|PWY-7219| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7219| ))
# pathway-components
# (pathway-components '|PWY-6268| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6268| ))
# pathway-components
# (pathway-components '|PWY-5669| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5669| ))
# pathway-components
# (pathway-components '|GLYCOCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLYCOCAT-PWY| ))
# pathway-components
# (pathway-components '|GLYOXDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLYOXDEG-PWY| ))
# pathway-components
# (pathway-components '|PWY-7892| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7892| ))
# pathway-components
# (pathway-components '|PWY-5783| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5783| ))
# pathway-components
# (pathway-components '|PWY-7221| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7221| ))
# pathway-components
# (pathway-components '|PWY-6894| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6894| ))
# pathway-components
# (pathway-components '|PWY0-1545| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1545| ))
# pathway-components
# (pathway-components '|GLYCOLATEMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLYCOLATEMET-PWY| ))
# pathway-components
# (pathway-components '|PWY-7247| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7247| ))
# pathway-components
# (pathway-components '|PWY0-1587| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1587| ))
# pathway-components
# (pathway-components '|GLUTORN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLUTORN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1296| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1296| ))
# pathway-components
# (pathway-components '|PWY-6605| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6605| ))
# pathway-components
# (pathway-components '|PWY-6890| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6890| ))
# pathway-components
# (pathway-components '|PWY-5668| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5668| ))
# pathway-components
# (pathway-components '|PWY-7179| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7179| ))
# pathway-components
# (pathway-components '|PWY-6700| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6700| ))
# pathway-components
# (pathway-components '|PWY-5155| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5155| ))
# pathway-components
# (pathway-components '|PWY-6019| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6019| ))
# pathway-components
# (pathway-components '|PWY-6611| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6611| ))
# pathway-components
# (pathway-components '|PWY-6892| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6892| ))
# pathway-components
# (pathway-components '|PWY-5194| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5194| ))
# pathway-components
# (pathway-components '|PWY0-1391| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1391| ))
# pathway-components
# (pathway-components '|PWY0-1554| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1554| ))
# pathway-components
# (pathway-components '|PROSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PROSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY-6609| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6609| ))
# pathway-components
# (pathway-components '|PWY-6910| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6910| ))
# pathway-components
# (pathway-components '|GLUTATHIONESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLUTATHIONESYN-PWY| ))
# pathway-components
# (pathway-components '|PWY-40| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-40| ))
# pathway-components
# (pathway-components '|PWY-5484| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5484| ))
# pathway-components
# (pathway-components '|PWY-4621| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-4621| ))
# pathway-components
# (pathway-components '|PWY0-901| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-901| ))
# pathway-components
# (pathway-components '|PWY-46| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-46| ))
# pathway-components
# (pathway-components '|PWY-6620| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6620| ))
# pathway-components
# (pathway-components '|PWY-6519| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6519| ))
# pathway-components
# (pathway-components '|SALVPURINE2-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|SALVPURINE2-PWY| ))
# pathway-components
# (pathway-components '|BETSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|BETSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY-5453| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5453| ))
# pathway-components
# (pathway-components '|GLUT-REDOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLUT-REDOX-PWY| ))
# pathway-components
# (pathway-components '|PWY-7870| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7870| ))
# pathway-components
# (pathway-components '|BSUBPOLYAMSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|BSUBPOLYAMSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY-6618| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6618| ))
# pathway-components
# (pathway-components '|THIOREDOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|THIOREDOX-PWY| ))
# pathway-components
# (pathway-components '|CYSTSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|CYSTSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY-5386| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5386| ))
# pathway-components
# (pathway-components '|PWY-6282| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6282| ))
# pathway-components
# (pathway-components '|PWY-5188| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5188| ))
# pathway-components
# (pathway-components '|PWY-6121| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6121| ))
# pathway-components
# (pathway-components '|TYRSYN| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|TYRSYN| ))
# pathway-components
# (pathway-components '|PWY0-862| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-862| ))
# pathway-components
# (pathway-components '|TCA| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|TCA| ))
# pathway-components
# (pathway-components '|PWY-6122| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6122| ))
# pathway-components
# (pathway-components '|PWY0-1305| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1305| ))
# pathway-components
# (pathway-components '|GLUCOSE1PMETAB-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLUCOSE1PMETAB-PWY| ))
# pathway-components
# (pathway-components '|GLYCOLYSIS| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLYCOLYSIS| ))
# pathway-components
# (pathway-components '|GLYSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLYSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY-7180| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7180| ))
# pathway-components
# (pathway-components '|PWY0-1477| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1477| ))
# pathway-components
# (pathway-components '|PWY-7183| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7183| ))
# pathway-components
# (pathway-components '|PWY0-1309| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1309| ))
# pathway-components
# (pathway-components '|PWY0-1299| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1299| ))
# pathway-components
# (pathway-components '|NONOXIPENT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|NONOXIPENT-PWY| ))
# pathway-components
# (pathway-components '|LEUSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|LEUSYN-PWY| ))
# pathway-components
# (pathway-components '|RIBOKIN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|RIBOKIN-PWY| ))
# pathway-components
# (pathway-components '|PWY-7205| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7205| ))
# pathway-components
# (pathway-components '|FUCCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|FUCCAT-PWY| ))
# pathway-components
# (pathway-components '|DETOX1-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|DETOX1-PWY| ))
# pathway-components
# (pathway-components '|PHESYN| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PHESYN| ))
# pathway-components
# (pathway-components '|MANNCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|MANNCAT-PWY| ))
# pathway-components
# (pathway-components '|PWY-6147| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6147| ))
# pathway-components
# (pathway-components '|PWY0-1337| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1337| ))
# pathway-components
# (pathway-components '|PWY0-181| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-181| ))
# pathway-components
# (pathway-components '|PWY0-1021| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1021| ))
# pathway-components
# (pathway-components '|PWY0-1301| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1301| ))
# pathway-components
# (pathway-components '|PWY0-44| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-44| ))
# pathway-components
# (pathway-components '|PWY0-163| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-163| ))
# pathway-components
# (pathway-components '|NRI-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|NRI-PWY| ))
# pathway-components
# (pathway-components '|PWY0-42| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-42| ))
# pathway-components
# (pathway-components '|PWY0-1569| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1569| ))
# pathway-components
# (pathway-components '|LYXMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|LYXMET-PWY| ))
# pathway-components
# (pathway-components '|ALANINE-VALINESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ALANINE-VALINESYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1300| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1300| ))
# pathway-components
# (pathway-components '|PWY0-1499| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1499| ))
# pathway-components
# (pathway-components '|PWY0-1314| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1314| ))
# pathway-components
# (pathway-components '|PWY0-1527| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1527| ))
# pathway-components
# (pathway-components '|OXIDATIVEPENT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|OXIDATIVEPENT-PWY| ))
# pathway-components
# (pathway-components '|PWY-7193| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7193| ))
# pathway-components
# (pathway-components '|ALANINE-SYN2-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ALANINE-SYN2-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1317| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1317| ))
# pathway-components
# (pathway-components '|LIPA-CORESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|LIPA-CORESYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1470| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1470| ))
# pathway-components
# (pathway-components '|PWY0-1315| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1315| ))
# pathway-components
# (pathway-components '|SERSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|SERSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1280| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1280| ))
# pathway-components
# (pathway-components '|PWY-5698| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5698| ))
# pathway-components
# (pathway-components '|FAO-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|FAO-PWY| ))
# pathway-components
# (pathway-components '|PWY-7344| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7344| ))
# pathway-components
# (pathway-components '|PWY-7187| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7187| ))
# pathway-components
# (pathway-components '|PWY0-1503| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1503| ))
# pathway-components
# (pathway-components '|GLUAMCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLUAMCAT-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1264| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1264| ))
# pathway-components
# (pathway-components '|ASPARTATESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ASPARTATESYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1221| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1221| ))
# pathway-components
# (pathway-components '|PWY-7343| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7343| ))
# pathway-components
# (pathway-components '|NAGLIPASYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|NAGLIPASYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1482| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1482| ))
# pathway-components
# (pathway-components '|PUTDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PUTDEG-PWY| ))
# pathway-components
# (pathway-components '|TRPSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|TRPSYN-PWY| ))
# pathway-components
# (pathway-components '|CARNMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|CARNMET-PWY| ))
# pathway-components
# (pathway-components '|PWY-7335| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7335| ))
# pathway-components
# (pathway-components '|PWY-5837| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5837| ))
# pathway-components
# (pathway-components '|KDO-LIPASYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|KDO-LIPASYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1509| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1509| ))
# pathway-components
# (pathway-components '|GLNSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLNSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1471| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1471| ))
# pathway-components
# (pathway-components '|PWY-7346| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7346| ))
# pathway-components
# (pathway-components '|PWY-6708| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6708| ))
# pathway-components
# (pathway-components '|PWY0-1487| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1487| ))
# pathway-components
# (pathway-components '|PWY-5084| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5084| ))
# pathway-components
# (pathway-components '|PWY0-1261| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1261| ))
# pathway-components
# (pathway-components '|ILEUSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ILEUSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY-7544| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7544| ))
# pathway-components
# (pathway-components '|PWY0-1241| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1241| ))
# pathway-components
# (pathway-components '|UDPNAGSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|UDPNAGSYN-PWY| ))
# pathway-components
# (pathway-components '|MENAQUINONESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|MENAQUINONESYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1515| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1515| ))
# pathway-components
# (pathway-components '|PWY-7545| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7545| ))
# pathway-components
# (pathway-components '|ASPARAGINESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ASPARAGINESYN-PWY| ))
# pathway-components
# (pathway-components '|FASYN-ELONG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|FASYN-ELONG-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1329| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1329| ))
# pathway-components
# (pathway-components '|PWY-6123| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6123| ))
# pathway-components
# (pathway-components '|PWY-66| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-66| ))
# pathway-components
# (pathway-components '|PWY0-1493| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1493| ))
# pathway-components
# (pathway-components '|PWY0-521| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-521| ))
# pathway-components
# (pathway-components '|PWY0-1334| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1334| ))
# pathway-components
# (pathway-components '|PWY-5965| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5965| ))
# pathway-components
# (pathway-components '|ASPARAGINE-BIOSYNTHESIS| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ASPARAGINE-BIOSYNTHESIS| ))
# pathway-components
# (pathway-components '|PWY-4381| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-4381| ))
# pathway-components
# (pathway-components '|PWY0-1335| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1335| ))
# pathway-components
# (pathway-components '|PWY-5686| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5686| ))
# pathway-components
# (pathway-components '|MANNIDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|MANNIDEG-PWY| ))
# pathway-components
# (pathway-components '|PWY-5659| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5659| ))
# pathway-components
# (pathway-components '|PPGPPMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PPGPPMET-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1550| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1550| ))
# pathway-components
# (pathway-components '|PWY0-1353| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1353| ))
# pathway-components
# (pathway-components '|PWY-5966| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5966| ))
# pathway-components
# (pathway-components '|HOMOSER-THRESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|HOMOSER-THRESYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1544| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1544| ))
# pathway-components
# (pathway-components '|NONMEVIPP-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|NONMEVIPP-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1498| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1498| ))
# pathway-components
# (pathway-components '|PWY0-1561| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1561| ))
# pathway-components
# (pathway-components '|GLUTSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLUTSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1565| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1565| ))
# pathway-components
# (pathway-components '|PWY0-1468| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1468| ))
# pathway-components
# (pathway-components '|PWY0-1567| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1567| ))
# pathway-components
# (pathway-components '|GLUTSYNIII-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLUTSYNIII-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1568| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1568| ))
# pathway-components
# (pathway-components '|PWY0-1546| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1546| ))
# pathway-components
# (pathway-components '|CYANCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|CYANCAT-PWY| ))
# pathway-components
# (pathway-components '|BGALACT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|BGALACT-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1501| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1501| ))
# pathway-components
# (pathway-components '|VALSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|VALSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1466| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1466| ))
# pathway-components
# (pathway-components '|PWY-1269| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-1269| ))
# pathway-components
# (pathway-components '|GALACTITOLCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GALACTITOLCAT-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1481| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1481| ))
# pathway-components
# (pathway-components '|IDNCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|IDNCAT-PWY| ))
# pathway-components
# (pathway-components '|PWY-4261| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-4261| ))
# pathway-components
# (pathway-components '|PWY0-1182| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1182| ))
# pathway-components
# (pathway-components '|HISTSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|HISTSYN-PWY| ))
# pathway-components
# (pathway-components '|TREDEGLOW-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|TREDEGLOW-PWY| ))
# pathway-components
# (pathway-components '|PWY-2161| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-2161| ))
# pathway-components
# (pathway-components '|DTDPRHAMSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|DTDPRHAMSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1506| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1506| ))
# pathway-components
# (pathway-components '|PWY0-1306| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1306| ))
# pathway-components
# (pathway-components '|ACETOACETATE-DEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ACETOACETATE-DEG-PWY| ))
# pathway-components
# (pathway-components '|ENTNER-DOUDOROFF-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ENTNER-DOUDOROFF-PWY| ))
# pathway-components
# (pathway-components '|PWY-6614| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6614| ))
# pathway-components
# (pathway-components '|DAPLYSINESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|DAPLYSINESYN-PWY| ))
# pathway-components
# (pathway-components '|RHAMCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|RHAMCAT-PWY| ))
# pathway-components
# (pathway-components '|1CMET2-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|1CMET2-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1590| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1590| ))
# pathway-components
# (pathway-components '|PWY-7315| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7315| ))
# pathway-components
# (pathway-components '|GLYCOGENSYNTH-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLYCOGENSYNTH-PWY| ))
# pathway-components
# (pathway-components '|GALACTCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GALACTCAT-PWY| ))
# pathway-components
# (pathway-components '|DARABCATK12-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|DARABCATK12-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1485| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1485| ))
# pathway-components
# (pathway-components '|PWY0-1338| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1338| ))
# pathway-components
# (pathway-components '|PWY-6543| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6543| ))
# pathway-components
# (pathway-components '|ARABCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|ARABCAT-PWY| ))
# pathway-components
# (pathway-components '|PWY0-661| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-661| ))
# pathway-components
# (pathway-components '|PWY0-1514| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1514| ))
# pathway-components
# (pathway-components '|PWY-7242| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7242| ))
# pathway-components
# (pathway-components '|PWY0-43| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-43| ))
# pathway-components
# (pathway-components '|PWY0-1324| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1324| ))
# pathway-components
# (pathway-components '|GLUCONEO-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GLUCONEO-PWY| ))
# pathway-components
# (pathway-components '|XYLCAT-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|XYLCAT-PWY| ))
# pathway-components
# (pathway-components '|PWY0-662| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-662| ))
# pathway-components
# (pathway-components '|SORBDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|SORBDEG-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1303| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1303| ))
# pathway-components
# (pathway-components '|PWY0-1492| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1492| ))
# pathway-components
# (pathway-components '|PWY0-301| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-301| ))
# pathway-components
# (pathway-components '|GALACTMETAB-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|GALACTMETAB-PWY| ))
# pathway-components
# (pathway-components '|PWY-5852| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-5852| ))
# pathway-components
# (pathway-components '|PLPSAL-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PLPSAL-PWY| ))
# pathway-components
# (pathway-components '|PWY0-321| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-321| ))
# pathway-components
# (pathway-components '|PWY-6608| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6608| ))
# pathway-components
# (pathway-components '|PWY-4121| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-4121| ))
# pathway-components
# (pathway-components '|PWY0-1519| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1519| ))
# pathway-components
# (pathway-components '|PWY-6961| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6961| ))
# pathway-components
# (pathway-components '|SALVADEHYPOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|SALVADEHYPOX-PWY| ))
# pathway-components
# (pathway-components '|PYRIDOXSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PYRIDOXSYN-PWY| ))
# pathway-components
# (pathway-components '|PWY-6617| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6617| ))
# pathway-components
# (pathway-components '|PWY0-1591| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1591| ))
# pathway-components
# (pathway-components '|PWY0-1497| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1497| ))
# pathway-components
# (pathway-components '|PWY0-1507| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1507| ))
# pathway-components
# (pathway-components '|PWY-6556| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-6556| ))
# pathway-components
# (pathway-components '|PWY0-1588| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1588| ))
# pathway-components
# (pathway-components '|PROPIONMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PROPIONMET-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1295| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1295| ))
# pathway-components
# (pathway-components '|RIBOSYN2-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|RIBOSYN2-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1597| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1597| ))
# pathway-components
# (pathway-components '|PWY-7195| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY-7195| ))
# pathway-components
# (pathway-components '|PWY0-1458| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1458| ))
# pathway-components
# (pathway-components '|PWY0-1321| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1321| ))
# pathway-components
# (pathway-components '|PWY0-1500| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1500| ))
# pathway-components
# (pathway-components '|HCAMHPDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|HCAMHPDEG-PWY| ))
# pathway-components
# (pathway-components '|PWY0-1336| )
# (with-organism (:org-id '|ECOLI|) (pathway-components '|PWY0-1336| ))
# [[[u'|RXN0-5264|', u'|RXN0-5388|']], 1, 2, 2]

# %%
lst = []
for pwy in ecoli.all_pathways(selector = ':all', base = True):
    lst.append(ecoli.noncontiguous_pathway_p(pwy = pwy))
lst[-10:]
# Out:
# all-pathways
# (all-pathways ::all t )
# (with-organism (:org-id '|ECOLI|) (all-pathways ::all t ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1347| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1474| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-6690| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1348| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1348| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-5162| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-5162| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1352| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1352| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1505| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1505| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1355| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1355| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|2PHENDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|2PHENDEG-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1465| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|TRESYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|TRESYN-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PANTO-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PANTO-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1356| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1356| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|ETOH-ACETYLCOA-ANA-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|ETOH-ACETYLCOA-ANA-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1483| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1483| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1573| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1573| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1586| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1586| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|GLUCONSUPER-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|GLUCONSUPER-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1576| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1576| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|GLYCEROLMETAB-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|GLYCEROLMETAB-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1512| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1512| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1577| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1577| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-5123| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-5123| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1313| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1313| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-6387| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-6387| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PYRIDNUCSAL-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PYRIDNUCSAL-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1578| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1578| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1490| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1490| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1581| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1581| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY3O-4106| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY3O-4106| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|KDOSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|KDOSYN-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-7761| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-7761| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1582| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1582| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-7971| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-7971| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1534| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1534| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-6952| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-6952| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1518| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1518| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-7184| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-7184| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1584| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1584| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-6038| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-6038| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PYRIDNUCSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PYRIDNUCSYN-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1585| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1585| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-981| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-981| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1495| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1495| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-7181| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-7181| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-7801| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-7801| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PYRUVDEHYD-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PYRUVDEHYD-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-5509| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-5509| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-5350| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-5350| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1559| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1559| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|ALKANEMONOX-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|ALKANEMONOX-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|HOMOSER-METSYN-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|HOMOSER-METSYN-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-6153| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-6153| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1535| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1535| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-7206| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-7206| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|AST-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|AST-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-5340| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-5340| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-823| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-823| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-541| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-541| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|THREONINE-DEG2-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|THREONINE-DEG2-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-
)
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1591| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1497| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1497| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1507| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1507| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-6556| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-6556| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1588| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1588| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PROPIONMET-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PROPIONMET-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1295| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1295| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|RIBOSYN2-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|RIBOSYN2-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1597| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1597| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY-7195| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY-7195| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1458| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1458| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1321| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1321| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1500| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1500| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|HCAMHPDEG-PWY| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|HCAMHPDEG-PWY| ))
# noncontiguous-pathway-p
# (noncontiguous-pathway-p '|PWY0-1336| )
# (with-organism (:org-id '|ECOLI|) (noncontiguous-pathway-p '|PWY0-1336| ))
# [False, False, False, False, False, True, False, True, False, False]

# %%
"""
rxn1
An instance of the class |Reactions|. 
rxn2
An instance of the class |Reactions|. 
pwy
An instance of the class |Pathways|. 
"""

lst = []
for pwy in ecoli.all_pathways(selector = ':all', base = True)[0:10]:
    for rxn1 in ecoli.all_rxns(rxn_type = ':all')[0:10]:
        for rxn2 in ecoli.all_rxns(rxn_type = ':all')[0:10]:
            lst.append([rxn1, rxn2, ecoli.rxns_adjacent_in_pwy_p(rxn1 = rxn1, rxn2 = rxn2, pwy = pwy)])
#     lst.append(ecoli.rxns_adjacent_in_pwy_p(rxn1 = u'|RXN0-5264|', rxn2 = u'|RXN0-5388|', pwy = pwy))
lst[-10:]
# Out:
# all-pathways
# (all-pathways ::all t )
# (with-organism (:org-id '|ECOLI|) (all-pathways ::all t ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN-15348| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN-15348| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|LACTALDREDUCT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|LACTALDREDUCT-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|PFLDEACTIV-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|PFLDEACTIV-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|OHMETPYRKIN-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|OHMETPYRKIN-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-7094| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-7094| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-7298| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-7298| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-1137| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-1137| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|BADH-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|BADH-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|DMKCYT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|DMKCYT-RXN| '|PWY0-1347| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN-15348| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN-15348| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|PFLDEACTIV-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|PFLDEACTIV-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-7094| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-7094| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-7298| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-7298| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-1137| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-1137| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|BADH-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|BADH-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|DMKCYT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|DMKCYT-RXN| '|PWY0-1347| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN-15348| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN-15348| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|PFLDEACTIV-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|PFLDEACTIV-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7094| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7094| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7298| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7298| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-1137| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-1137| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|BADH-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|BADH-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|DMKCYT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|DMKCYT-RXN| '|PWY0-1347| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN-15348| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN-15348| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|PFLDEACTIV-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|PFLDEACTIV-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-7094| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-7094| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-7298| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-7298| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-1137| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-1137| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|BADH-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|BADH-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|DMKCYT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|DMKCYT-RXN| '|PWY0-1347| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN-15348| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN-15348| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|LACTALDREDUCT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|LACTALDREDUCT-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|PFLDEACTIV-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|PFLDEACTIV-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|OHMETPYRKIN-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|OHMETPYRKIN-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-7094| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-7094| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-7298| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-7298| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-1137| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-1137| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|BADH-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|BADH-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|DMKCYT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|DMKCYT-RXN| '|PWY0-1347| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN-15348| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN-15348| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|PFLDEACTIV-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|PFLDEACTIV-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-7094| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-7094| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-7298| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-7298| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-1137| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-1137| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|BADH-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|BADH-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|DMKCYT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|DMKCYT-RXN| '|PWY0-1347| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN-15348| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN-15348| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|LACTALDREDUCT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|LACTALDREDUCT-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|PFLDEACTIV-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|PFLDEACTIV-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|OHMETPYRKIN-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|OHMETPYRKIN-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-7094| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-7094| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-7298| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-7298| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-1137| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-1137| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|BADH-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|BADH-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|DMKCYT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|DMKCYT-RXN| '|PWY0-1347| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN-15348| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN-15348| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|LACTALDREDUCT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|LACTALDREDUCT-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|PFLDEACTIV-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|PFLDEACTIV-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|OHMETPYRKIN-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|OHMETPYRKIN-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-7094| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-7094| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-7298| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-7298| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-1137| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-1137| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|BADH-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|BADH-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|DMKCYT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|DMKCYT-RXN| '|PWY0-1347| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN-15348| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN-15348| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|PFLDEACTIV-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|PFLDEACTIV-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-7094| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-7094| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-7298| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-7298| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-1137| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-1137| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|BADH-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|BADH-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|DMKCYT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|DMKCYT-RXN| '|PWY0-1347| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN-15348| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN-15348| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|PFLDEACTIV-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|PFLDEACTIV-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-7094| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-7094| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-7298| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-7298| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-1137| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-1137| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|BADH-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|BADH-RXN| '|PWY0-1347| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|DMKCYT-RXN| '|PWY0-1347| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|DMKCYT-RXN| '|PWY0-1347| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN-15348| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN-15348| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|LACTALDREDUCT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|LACTALDREDUCT-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|PFLDEACTIV-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|PFLDEACTIV-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|OHMETPYRKIN-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|OHMETPYRKIN-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-7094| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-7094| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-7298| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-7298| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-1137| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-1137| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|BADH-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|BADH-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|DMKCYT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|DMKCYT-RXN| '|PWY0-1474| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN-15348| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN-15348| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|PFLDEACTIV-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|PFLDEACTIV-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-7094| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-7094| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-7298| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-7298| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-1137| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-1137| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|BADH-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|BADH-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|DMKCYT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|DMKCYT-RXN| '|PWY0-1474| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN-15348| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN-15348| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|PFLDEACTIV-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|PFLDEACTIV-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7094| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7094| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7298| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7298| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-1137| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-1137| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|BADH-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|BADH-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|DMKCYT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|DMKCYT-RXN| '|PWY0-1474| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN-15348| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN-15348| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|PFLDEACTIV-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|PFLDEACTIV-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-7094| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-7094| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-7298| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-7298| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-1137| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-1137| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|BADH-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|BADH-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|DMKCYT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|DMKCYT-RXN| '|PWY0-1474| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN-15348| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN-15348| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|LACTALDREDUCT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|LACTALDREDUCT-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|PFLDEACTIV-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|PFLDEACTIV-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|OHMETPYRKIN-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|OHMETPYRKIN-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-7094| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-7094| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-7298| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-7298| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-1137| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-1137| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|BADH-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|BADH-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|DMKCYT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|DMKCYT-RXN| '|PWY0-1474| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN-15348| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN-15348| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|PFLDEACTIV-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|PFLDEACTIV-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-7094| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-7094| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-7298| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-7298| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-1137| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-1137| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|BADH-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|BADH-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|DMKCYT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|DMKCYT-RXN| '|PWY0-1474| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN-15348| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN-15348| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|LACTALDREDUCT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|LACTALDREDUCT-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|PFLDEACTIV-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|PFLDEACTIV-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|OHMETPYRKIN-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|OHMETPYRKIN-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-7094| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-7094| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-7298| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-7298| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-1137| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-1137| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|BADH-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|BADH-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|DMKCYT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|DMKCYT-RXN| '|PWY0-1474| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN-15348| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN-15348| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|LACTALDREDUCT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|LACTALDREDUCT-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|PFLDEACTIV-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|PFLDEACTIV-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|OHMETPYRKIN-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|OHMETPYRKIN-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-7094| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-7094| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-7298| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-7298| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-1137| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-1137| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|BADH-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|BADH-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|DMKCYT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|DMKCYT-RXN| '|PWY0-1474| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN-15348| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN-15348| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|PFLDEACTIV-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|PFLDEACTIV-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-7094| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-7094| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-7298| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-7298| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-1137| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-1137| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|BADH-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|BADH-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|DMKCYT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|DMKCYT-RXN| '|PWY0-1474| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN-15348| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN-15348| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|PFLDEACTIV-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|PFLDEACTIV-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-7094| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-7094| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-7298| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-7298| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-1137| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-1137| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|BADH-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|BADH-RXN| '|PWY0-1474| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|DMKCYT-RXN| '|PWY0-1474| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|DMKCYT-RXN| '|PWY0-1474| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN-15348| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN-15348| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|LACTALDREDUCT-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|LACTALDREDUCT-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|PFLDEACTIV-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|PFLDEACTIV-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|OHMETPYRKIN-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|OHMETPYRKIN-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-7094| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-7094| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|TRIOSEPISOMERIZATION-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|TRIOSEPISOMERIZATION-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-7298| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-7298| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-1137| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|RXN0-1137| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|BADH-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|BADH-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN-15348| '|DMKCYT-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN-15348| '|DMKCYT-RXN| '|PWY-6690| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN-15348| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN-15348| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|LACTALDREDUCT-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|LACTALDREDUCT-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|PFLDEACTIV-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|PFLDEACTIV-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|OHMETPYRKIN-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|OHMETPYRKIN-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-7094| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-7094| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-7298| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-7298| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-1137| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|RXN0-1137| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|BADH-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|BADH-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|DMKCYT-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|LACTALDREDUCT-RXN| '|DMKCYT-RXN| '|PWY-6690| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN-15348| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN-15348| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|LACTALDREDUCT-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|LACTALDREDUCT-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|PFLDEACTIV-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|PFLDEACTIV-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|OHMETPYRKIN-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|OHMETPYRKIN-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7094| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7094| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7298| '|PWY-6690| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7298| '|PWY-6690| ))
# rxns-adjacent-in-pwy-p
# ...
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7298| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-7298| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-1137| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|RXN0-1137| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|BADH-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|BADH-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|DMKCYT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|PFLDEACTIV-RXN| '|DMKCYT-RXN| '|PWY0-1465| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN-15348| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN-15348| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|PFLDEACTIV-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|PFLDEACTIV-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-7094| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-7094| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-7298| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-7298| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-1137| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|RXN0-1137| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|BADH-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|BADH-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|DMKCYT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|OHMETPYRKIN-RXN| '|DMKCYT-RXN| '|PWY0-1465| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN-15348| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN-15348| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|LACTALDREDUCT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|LACTALDREDUCT-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|PFLDEACTIV-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|PFLDEACTIV-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|OHMETPYRKIN-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|OHMETPYRKIN-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-7094| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-7094| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-7298| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-7298| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-1137| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|RXN0-1137| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|BADH-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|BADH-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7094| '|DMKCYT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7094| '|DMKCYT-RXN| '|PWY0-1465| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN-15348| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN-15348| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|PFLDEACTIV-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|PFLDEACTIV-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-7094| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-7094| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-7298| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-7298| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-1137| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|RXN0-1137| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|BADH-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|BADH-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|DMKCYT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|TRIOSEPISOMERIZATION-RXN| '|DMKCYT-RXN| '|PWY0-1465| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN-15348| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN-15348| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|LACTALDREDUCT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|LACTALDREDUCT-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|PFLDEACTIV-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|PFLDEACTIV-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|OHMETPYRKIN-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|OHMETPYRKIN-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-7094| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-7094| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-7298| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-7298| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-1137| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|RXN0-1137| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|BADH-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|BADH-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-7298| '|DMKCYT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-7298| '|DMKCYT-RXN| '|PWY0-1465| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN-15348| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN-15348| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|LACTALDREDUCT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|LACTALDREDUCT-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|PFLDEACTIV-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|PFLDEACTIV-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|OHMETPYRKIN-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|OHMETPYRKIN-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-7094| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-7094| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-7298| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-7298| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-1137| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|RXN0-1137| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|BADH-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|BADH-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|RXN0-1137| '|DMKCYT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|RXN0-1137| '|DMKCYT-RXN| '|PWY0-1465| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN-15348| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN-15348| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|PFLDEACTIV-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|PFLDEACTIV-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-7094| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-7094| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-7298| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-7298| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-1137| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|RXN0-1137| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|BADH-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|BADH-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|BADH-RXN| '|DMKCYT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|BADH-RXN| '|DMKCYT-RXN| '|PWY0-1465| ))
# all-rxns
# (all-rxns ::all )
# (with-organism (:org-id '|ECOLI|) (all-rxns ::all ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN-15348| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN-15348| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|LACTALDREDUCT-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|PFLDEACTIV-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|PFLDEACTIV-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|OHMETPYRKIN-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-7094| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-7094| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|TRIOSEPISOMERIZATION-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-7298| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-7298| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-1137| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|RXN0-1137| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|BADH-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|BADH-RXN| '|PWY0-1465| ))
# rxns-adjacent-in-pwy-p
# (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|DMKCYT-RXN| '|PWY0-1465| )
# (with-organism (:org-id '|ECOLI|) (rxns-adjacent-in-pwy-p '|DMKCYT-RXN| '|DMKCYT-RXN| '|PWY0-1465| ))
# [[u'|DMKCYT-RXN|', u'|RXN-15348|', False],
#  [u'|DMKCYT-RXN|', u'|LACTALDREDUCT-RXN|', False],
#  [u'|DMKCYT-RXN|', u'|PFLDEACTIV-RXN|', False],
#  [u'|DMKCYT-RXN|', u'|OHMETPYRKIN-RXN|', False],
#  [u'|DMKCYT-RXN|', u'|RXN0-7094|', False],
#  [u'|DMKCYT-RXN|', u'|TRIOSEPISOMERIZATION-RXN|', False],
#  [u'|DMKCYT-RXN|', u'|RXN0-7298|', False],
#  [u'|DMKCYT-RXN|', u'|RXN0-1137|', False],
#  [u'|DMKCYT-RXN|', u'|BADH-RXN|', False],
#  [u'|DMKCYT-RXN|', u'|DMKCYT-RXN|', False]]
